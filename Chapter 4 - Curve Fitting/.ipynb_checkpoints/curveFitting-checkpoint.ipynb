# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    data1     data2
# 0    390 -0.050356
# 1    391 -0.060097
# 2    393 -0.041901
# 3    394 -0.050985
# 4    396 -0.059913

# %%
fig, ax = plt.subplots(figsize=(8, 6))
blue = sns.color_palette()[0]
ax.scatter(df.data1, df.data2, c=blue, alpha=0.75);

ax.set_xlabel('Data1');

ax.set_ylabel('Data2');

# %%
X = df.iloc[:,0:1].values
print('X Shape = ', X.shape)

Y = df.iloc[:,1:2].values
print('Y Shape = ',Y.shape)
# Out:
# X Shape =  (221, 1)
# Y Shape =  (221, 1)

# %% [markdown]
# # Linear Regression using Sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression1 = LinearRegression();
print(linear_regression1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linear_regression1.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# # Polynomial Linear Regression using Sklearn

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
_,nFeatures = df.shape
print('Number of Features = ' , nFeatures)
poly_reg = PolynomialFeatures(degree=nFeatures)
X_poly = poly_reg.fit_transform(X) # [b0x^0  b1x^1  b2x^2  ...  bNx^N]
print(X_poly[0:5 , :])
# Out:
# Number of Features =  2
# [[1.00000e+00 3.90000e+02 1.52100e+05]
#  [1.00000e+00 3.91000e+02 1.52881e+05]
#  [1.00000e+00 3.93000e+02 1.54449e+05]
#  [1.00000e+00 3.94000e+02 1.55236e+05]
#  [1.00000e+00 3.96000e+02 1.56816e+05]]

# %% [markdown]
# ## Linear Regression for the new X poly Dataframe

# %%
linear_regression2 = LinearRegression();
linear_regression2.fit(X_poly,Y);

# %% [markdown]
# # Plot the Data

# %%
fig, ax = plt.subplots(figsize=(8, 6))
blue = sns.color_palette()[0]
ax.scatter(X, Y, c=blue, alpha=0.75);

plt.plot(X , linear_regression1.predict(X) , color='red')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
blue = sns.color_palette()[0]
ax.scatter(X, Y, c=blue, alpha=0.75);

plt.plot(X , linear_regression2.predict(X_poly) , color='red')
plt.show()
